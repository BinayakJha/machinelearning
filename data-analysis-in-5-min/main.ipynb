# %%
# do pip install pandas-profiling and pip install pandas

import pandas as pd

df = pd.read_csv('housing.csv')
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2         496         177         7.2574              352100        NEAR BAY
# 3         558         219         5.6431              341300        NEAR BAY
# 4         565         259         3.8462              342200        NEAR BAY

# %%
from pandas_profiling import ProfileReport

# Generate a report
profile = ProfileReport(df)
profile.to_file(output_file="housing.html")
# Out:
# Summarize dataset: 100%|██████████| 23/23 [00:39<00:00,  1.73s/it, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:10<00:00, 10.46s/it]
# Render HTML: 100%|██████████| 1/1 [00:06<00:00,  6.34s/it]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 23.26it/s]

# %%
import matplotlib.pyplot as plt

df.hist(bins=50, figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'longitude'}>,
#         <AxesSubplot:title={'center':'latitude'}>,
#         <AxesSubplot:title={'center':'housing_median_age'}>],
#        [<AxesSubplot:title={'center':'total_rooms'}>,
#         <AxesSubplot:title={'center':'total_bedrooms'}>,
#         <AxesSubplot:title={'center':'population'}>],
#        [<AxesSubplot:title={'center':'households'}>,
#         <AxesSubplot:title={'center':'median_income'}>,
#         <AxesSubplot:title={'center':'median_house_value'}>]],
#       dtype=object)

# %%
from pandas_profiling import ProfileReport

# Generate a report
profile = ProfileReport(df)
profile.to_widgets()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-c6a567b6affd> in <module>
#       3 # Generate a report
#       4 profile = ProfileReport(df)
# ----> 5 profile.to_widgets(output_file="housing.html")
#
# TypeError: to_widgets() got an unexpected keyword argument 'output_file'
