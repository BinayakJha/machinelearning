# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv')

# %%
df.head()
# Out:
#        SYMBOL  SERIES         DATE1  PREV_CLOSE  OPEN_PRICE  HIGH_PRICE  \
# 0   20MICRONS      EQ   20-Jul-2021       67.60       68.90       69.15
# 1  21STCENMGM      EQ   20-Jul-2021       22.80       22.80       22.80
# 2  3IINFOTECH      BE   20-Jul-2021        9.35        9.45        9.45
# 3     3MINDIA      EQ   20-Jul-2021    24455.50    24500.00    24674.00
# 4      3PLAND      BE   20-Jul-2021       17.00       17.85       17.85
#
#    LOW_PRICE LAST_PRICE  CLOSE_PRICE  AVG_PRICE  TTL_TRD_QNTY  TURNOVER_LACS  \
# 0      65.60      66.15        66.25      67.32        345355         232.50
# 1      22.35      22.35        22.35      22.38          1655           0.37
# 2       8.90        9.1         9.05       9.10       4785318         435.67
# 3   23932.95      24368     24258.70   24137.97          3530         852.07
# 4      16.15      16.75        17.05      17.17         44196           7.59
#
#    NO_OF_TRADES DELIV_QTY DELIV_PER
# ...

# %%
import matplotlib.pyplot as plt

df.hist(bins=50, figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'PREV_CLOSE'}>,
#         <AxesSubplot:title={'center':'OPEN_PRICE'}>,
#         <AxesSubplot:title={'center':'HIGH_PRICE'}>],
#        [<AxesSubplot:title={'center':'LOW_PRICE'}>,
#         <AxesSubplot:title={'center':'CLOSE_PRICE'}>,
#         <AxesSubplot:title={'center':'AVG_PRICE'}>],
#        [<AxesSubplot:title={'center':'TTL_TRD_QNTY'}>,
#         <AxesSubplot:title={'center':'TURNOVER_LACS'}>,
#         <AxesSubplot:title={'center':'NO_OF_TRADES'}>]], dtype=object)

# %%
print(df['PREV_CLOSE'].dtype)
print(df['OPEN_PRICE'].dtype)
print(df[' SERIES'].dtype)
# Out:
# float64
# float64
# object

# %%
print(df['PREV_CLOSE'])
# Out:
# 0          67.60
# 1          22.80
# 2           9.35
# 3       24455.50
# 4          17.00
#           ...
# 2043       33.35
# 2044      249.05
# 2045      148.90
# 2046      164.75
# 2047     2232.95
# Name: PREV_CLOSE, Length: 2048, dtype: float64

# %%
print(df[' SERIES'].astype('category'))
# Out:
# 0        EQ
# 1        EQ
# 2        BE
# 3        EQ
# 4        BE
#        ...
# 2043     EQ
# 2044     EQ
# 2045     BE
# 2046     BE
# 2047     EQ
# Name:  SERIES, Length: 2048, dtype: category
# Categories (73, object): [' BE', ' BZ', ' E1', ' EQ', ..., ' Z9', ' ZE', ' ZF', ' ZI']

# %%
df2 = pd.read_csv('iphone_price.csv')
# df2 = pd.DataFrame(df2['version'],columns=['price'],index=['version','price'])

# %%
df2
# Out:
#         price
# version   NaN
# price     NaN

# %%
from matplotlib import pyplot as plt
from matplotlib import style

style.use('ggplot')
# plt.plot(df2['version'], label = 'version', linewidth = 3)
plt.plot(df2['price'], label = 'price',linewidth = 3)
# plt.hist(df2['price'], label = 'price',linewidth = 3)
plt.legend()
plt.show()

# %%
df2.plot.pie(y='price', figsize=(5, 5))
# Out:
# C:\Users\user\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1583: MatplotlibDeprecationWarning: normalize=None does not normalize if the sum is less than 1 but this behavior is deprecated since 3.3 until two minor releases later. After the deprecation period the default value will be normalize=True. To prevent normalization pass normalize=False
#   results = ax.pie(y, labels=blabels, **kwds)
# <AxesSubplot:ylabel='price'>
